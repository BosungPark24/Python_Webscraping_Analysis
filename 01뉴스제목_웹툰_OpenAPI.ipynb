# %% [markdown]
# ## 1. 뉴스제목 가져오기
# * user-agent 요청헤더를 반드시 설정해야 한다.

# %%
# !pip show requests
# Out:
# Name: requests
# Version: 2.32.2
# Summary: Python HTTP for Humans.
# Home-page: https://requests.readthedocs.io
# Author: Kenneth Reitz
# Author-email: me@kennethreitz.org
# License: Apache-2.0
# Location: C:\Users\r2com\anaconda3\Lib\site-packages
# Requires: certifi, charset-normalizer, idna, urllib3
# Required-by: anaconda-catalogs, anaconda-client, anaconda-cloud-auth, anaconda-project, conda, conda-build, conda-repo-cli, conda_package_streaming, cookiecutter, datashader, intake, jupyterlab_server, panel, requests-file, requests-toolbelt, Sphinx, streamlit, tldextract

# %%
# !pip show beautifulsoup4
# Out:
# Name: beautifulsoup4
# Version: 4.12.3
# Summary: Screen-scraping library
# Home-page:
# Author:
# Author-email: Leonard Richardson <leonardr@segfault.org>
# License: MIT License
# Location: C:\Users\r2com\anaconda3\Lib\site-packages
# Requires: soupsieve
# Required-by: conda-build, nbconvert

# %%
import requests
import bs4
from bs4 import BeautifulSoup

# %%
print(f'request ver {requests.__version__}' )
print('beautifulsoup {}'.format(bs4.__version__))
# Out:
# request ver 2.32.2
# beautifulsoup 4.12.3

# %% [markdown]
# ### 1. 뉴스 제목 추출하기

# %%
# IT/과학 뉴스
req_param = {
    'sid': 105
}
url = 'https://news.naver.com/section/{sid}'.format(**req_param)
print(url)
# 요청 헤더 설정 : 브라우저 정보
req_header = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
}
#requests 모듈을 사용해서 http 통신
res = requests.get(url, headers=req_header)
print(type(res))
print(res.status_code)
print(res.ok)
if res.ok:
    #소스보기 텍스트 가져오기
    html = res.text
    # parsing을 하기 위해서 BeautifulSoup 객체 생성
    soup = BeautifulSoup(html, "html.parser")
    #print(type(soup))
    '''
        <div class='sa_text'>
            <a href='http://...' class='sa_text_title'>
    '''
    #print(len(soup.select("div.sa_text a[href*='n.news.naver.com/mnews/article']"))) 
    #print(len(soup.select("div.sa_text a.sa_text_title")))
    atag_list = soup.select("div.sa_text a.sa_text_title")
    #print(type(atag_list))
    for atag in atag_list:
        #공백 제거 strip 함수 이용 / text 속성: tag 사이에 content
        title = atag.text.strip()
        # href 속성의 값을 추출하기
        url = atag['href']
        print(f'뉴스 제목 = {title}')
        print(f'뉴스 링크 = {url}')
        print('===============')
else:
    print(f'Error 발생 {res.status_code}')
# Out:
# https://news.naver.com/section/105
# <class 'requests.models.Response'>
# 200
# True
# 뉴스 제목 = 서울대 연구진, 배터리 ‘열폭주’ 원인 밝혔다...억제 방법까지 제시
# 뉴스 링크 = https://n.news.naver.com/mnews/article/021/0002652464
# ===============
# 뉴스 제목 = 엔씨소프트, 서브컬처 게임 개발사 '빅게임스튜디오' 지분 및 판권 투자
# 뉴스 링크 = https://n.news.naver.com/mnews/article/014/0005223399
# ===============
# 뉴스 제목 = 포스텍, 교수 정착지원금 최대 10억원으로…"우수 석학 유치"
# 뉴스 링크 = https://n.news.naver.com/mnews/article/001/0014854962
# ===============
# 뉴스 제목 = 카카오헬스케어, 대형병원과 연구 협력 네트워크 확대
# 뉴스 링크 = https://n.news.naver.com/mnews/article/001/0014855411
# ===============
# 뉴스 제목 = 더존비즈온, 2분기 영업익 204억원…전년比 19% ↑
# 뉴스 링크 = https://n.news.naver.com/mnews/article/018/0005805289
# ===============
# 뉴스 제목 = SK C&C, 베트남 ICT 기업과 글로벌 디지털 ESG 사업 협력
# 뉴스 링크 = https://n.news.naver.com/mnews/article/119/0002858766
# ===============
# 뉴스 제목 = 한국금거래소 "티메프 정산 이슈 관련 유동성 문제 없어"
# 뉴스 링크 = https://n.news.naver.com/mnews/article/029/0002892794
# ===============
# 뉴스 제목 = KISA, 구글·네이버 등과 '브라우저 안전 이용' 캠페인
# 뉴스 링크 = https://n.news.naver.com/mnews/article/018/0005805475
# ===============
# 뉴스 제목 = "적자는 면했다"...엔씨, 2분기 영업이익 88억원
# 뉴스 링크 = https://n.news.naver.com/mnews/article/008/0005073094
# ===============
# 뉴스 제목 = 5년만의 40도 돌파…'사상 최악' 2018년 기록 넘어설까?
# 뉴스 링크 = https://n.news.naver.com/mnews/article/584/0000028180
# ===============
# 뉴스 제목 = 코스피·코스닥 줄이어 서킷브레이커 발동
# 뉴스 링크 = https://n.news.naver.com/mnews/article/092/0002340932
# ===============
# 뉴스 제목 = 엔씨소프트, 적자 면했다… 2분기 영업이익 88억원
# 뉴스 링크 = https://n.news.naver.com/mnews/article/138/0002179213
# ===============
# 뉴스 제목 = 韓, 반도체 대중 수출 늘자… 中 “美 수출 제재 한계 드러나”
# 뉴스 링크 = https://n.news.naver.com/mnews/article/366/0001009937
# ===============
# 뉴스 제목 = ‘아재 입맛’인 줄 알았는데…믹스커피 MZ 업고 뜨나
# 뉴스 링크 = https://n.news.naver.com/mnews/article/092/0002340930
# ===============
# 뉴스 제목 = 네이버 '쇼핑 검색광고' 타고 온 '파워적립' 8년 만에 폐지
# 뉴스 링크 = https://n.news.naver.com/mnews/article/018/0005805500
# ===============
# 뉴스 제목 = 한국 양궁 금메달 5개 '싹쓸이'...비결은?
# 뉴스 링크 = https://n.news.naver.com/mnews/article/092/0002340929
# ===============
# 뉴스 제목 = [단독] 찜통더위 부른 북태평양 고기압…한중일 손잡고 예측 정확성 높인다
# 뉴스 링크 = https://n.news.naver.com/mnews/article/366/0001009933
# ===============
# 뉴스 제목 = 곤두박질치는 비트코인…'트럼프 약발' 보단 'R의 공포'
# 뉴스 링크 = https://n.news.naver.com/mnews/article/018/0005805497
# ===============
# 뉴스 제목 = 서브컬처 도전한다...엔씨, 빅게임스튜디오 지분 투자
# 뉴스 링크 = https://n.news.naver.com/mnews/article/029/0002892829
# ===============
# 뉴스 제목 = 이통3사 2분기 합산 영업익 예상 1.3조…전환지원금 타격 적었다
# 뉴스 링크 = https://n.news.naver.com/mnews/article/003/0012710549
# ===============
# 뉴스 제목 = 배터리 화재 키우는 '열폭주' 억제 방법 찾았다
# 뉴스 링크 = https://n.news.naver.com/mnews/article/584/0000028179
# ===============
# 뉴스 제목 = 티빙, 토종 OTT 1위 굳히기.. 쿠플, EPL로 만회 나선다
# 뉴스 링크 = https://n.news.naver.com/mnews/article/014/0005223409
# ===============
# 뉴스 제목 = M7 주가폭락에 실망한 투자자…"인내심 한계 달했다"
# 뉴스 링크 = https://n.news.naver.com/mnews/article/092/0002340926
# ===============
# 뉴스 제목 = 유라클, 수요예측 경쟁률 1065.8대 1…공모가 2만1000원 확정
# 뉴스 링크 = https://n.news.naver.com/mnews/article/138/0002179208
# ===============
# 뉴스 제목 = "뭘로 결제했더라"…티메프 환불, 페이·카드 희비 엇갈린다
# 뉴스 링크 = https://n.news.naver.com/mnews/article/018/0005805482
# ===============
# 뉴스 제목 = 엔씨, 빅게임스튜디오 370억 규모 지분·판권 투자
# 뉴스 링크 = https://n.news.naver.com/mnews/article/003/0012710504
# ===============
# 뉴스 제목 = 한국금거래소 “티메프 미정산 이슈, 유동성 영향 없다…매출 영향 미미”
# 뉴스 링크 = https://n.news.naver.com/mnews/article/138/0002179207
# ===============
# 뉴스 제목 = 아이폰, 이제야 한국 대우하나…신작 '1차 출시국' 포함된다
# 뉴스 링크 = https://n.news.naver.com/mnews/article/015/0005018184
# ===============
# 뉴스 제목 = 혼돈의 방송통신위원회와 ‘애국자가 없는 세상’
# 뉴스 링크 = https://n.news.naver.com/mnews/article/092/0002340921
# ===============
# 뉴스 제목 = 청라 화재서 촉발된 '中 배터리 포비아'…韓 3사 대체 가능성은 [소부장박대리]
# 뉴스 링크 = https://n.news.naver.com/mnews/article/138/0002179205
# ===============
# 뉴스 제목 = 말라리아·일본뇌염 모기 2배 넘게 급증…가장 확실한 예방법은
# 뉴스 링크 = https://n.news.naver.com/mnews/article/421/0007710891
# ===============
# 뉴스 제목 = “편의점 알바보다 열악한 처우” 이공계 석박사…연구생활장려금 지급, 숨통 트일까
# 뉴스 링크 = https://n.news.naver.com/mnews/article/016/0002345560
# ===============
# 뉴스 제목 = 전기차 배터리 열폭주 막을 방법 찾았다
# 뉴스 링크 = https://n.news.naver.com/mnews/article/366/0001009912
# ===============
# 뉴스 제목 = "美 상무부, 자율주행차 중국SW 사용 금지 규정 이달 발표 예정"
# 뉴스 링크 = https://n.news.naver.com/mnews/article/029/0002892817
# ===============
# 뉴스 제목 = 이공계 대학원생에 매달 80~110만원 지급…연구비 관리제도 개선
# 뉴스 링크 = https://n.news.naver.com/mnews/article/001/0014855246
# ===============
# 뉴스 제목 = 全 종목 '금메달' 석권 양궁…정의선 회장 40년 함께했다
# 뉴스 링크 = https://n.news.naver.com/mnews/article/092/0002340919
# ===============
# 뉴스 제목 = "언제까지 이렇게 덥나"…기상청 대신 인기 폭발한 날씨앱
# 뉴스 링크 = https://n.news.naver.com/mnews/article/008/0005073035
# ===============
# 뉴스 제목 = 美, 자율주행차에 중국산 SW·통신모듈 탑재 금지 추진
# 뉴스 링크 = https://n.news.naver.com/mnews/article/011/0004376131
# ===============
# 뉴스 제목 = 韓 해킹한 자료로 공장·지방개발 하려는 北... 北해커들 이곳 노린다
# 뉴스 링크 = https://n.news.naver.com/mnews/article/008/0005073031
# ===============
# 뉴스 제목 = 코오롱바이오텍, 골관절염 치료제 ‘TG-C’ 대량 생산 공정 개발
# 뉴스 링크 = https://n.news.naver.com/mnews/article/018/0005805447
# ===============
# 뉴스 제목 = “스마트폰 시장 3년 만에 성장세...삼성, 애플과 격차 벌릴 것”
# 뉴스 링크 = https://n.news.naver.com/mnews/article/366/0001009904
# ===============
# 뉴스 제목 = [제약바이오] 종근당, 바르는 소염진통제 케펨겔 출시 外
# 뉴스 링크 = https://n.news.naver.com/mnews/article/092/0002340918
# ===============
# 뉴스 제목 = '아마란스10' 200% 늘어난 더존비즈온, 하반기도 맑음
# 뉴스 링크 = https://n.news.naver.com/mnews/article/014/0005223355
# ===============
# 뉴스 제목 = 더존비즈온, 매출·영업이익 '쑥쑥'…"핵심사업 고른 성장"
# 뉴스 링크 = https://n.news.naver.com/mnews/article/648/0000027909
# ===============

# %% [markdown]
# ### 1.1 뉴스제목 추출하는 함수 선언하기

# %%
import requests
from bs4 import BeautifulSoup

def print_news(sid, section):    
    # 요청 Parameter
    req_param = {
        'sid': sid
    }
    url = 'https://news.naver.com/section/{sid}'.format(**req_param)
    
    print(f'======> {url} {section} 뉴스 <======')
    
    # 요청 헤더 설정 : 브라우저 정보
    req_header = {
        'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36'
    }
    res = requests.get(url, headers=req_header)
    if res.ok:
        #소스보기 텍스트 가져오기
        html = res.text
        # parsing을 하기 위해서 BeautifulSoup 객체 생성
        soup = BeautifulSoup(html, "html.parser")
        atag_list = soup.select("div.sa_text a.sa_text_title")
        for atag in atag_list:
            #공백 제거 strip 함수 이용 / text 속성: tag 사이에 content
            title = atag.text.strip()
            # href 속성의 값을 추출하기
            url = atag['href']
            print(f'뉴스 제목 = {title}')
            print(f'뉴스 링크 = {url}')
            print('===============')
    else:
        print(f'Error 발생 {res.status_code}')

# %%
section_dict = {100:'정치',101:'경제',102:'사회',103:'생활/문화',104:'세계',105:'IT/과학'}
print_news(103,section_dict[103])
# Out:
# ======> https://news.naver.com/section/103 생활/문화 뉴스 <======
# 뉴스 제목 = BMW, 7월 수입차 판매 1위…벤츠·테슬라·볼보·렉서스 뒤이어
# 뉴스 링크 = https://n.news.naver.com/mnews/article/011/0004376017
# ===============
# 뉴스 제목 = 전국 대부분 지역 폭염경보…요란한 소나기 유의[날씨]
# 뉴스 링크 = https://n.news.naver.com/mnews/article/422/0000674739
# ===============
# 뉴스 제목 = 현대자동차 군산 인증 중고차 센터 개소
# 뉴스 링크 = https://n.news.naver.com/mnews/article/016/0002345452
# ===============
# 뉴스 제목 = 이용훈 "오텔로는 모든 테너의 꿈…어렵지만 매력적"
# 뉴스 링크 = https://n.news.naver.com/mnews/article/003/0012710235
# ===============
# 뉴스 제목 = BMW코리아, 뉴 M4 컴페티션 M xDrive 쿠페·컨버터블 출시
# 뉴스 링크 = https://n.news.naver.com/mnews/article/421/0007710850
# ===============
# 뉴스 제목 = 마약 중독자 치료…지드래곤, 저스피스 재단 창립
# 뉴스 링크 = https://n.news.naver.com/mnews/article/023/0003850598
# ===============
# 뉴스 제목 = 다리 휘었나요? 그냥 두다간 ‘이 병’으로 이어질 수도
# 뉴스 링크 = https://n.news.naver.com/mnews/article/346/0000078429
# ===============
# 뉴스 제목 = 멸치 '조금', 생선 '한 토막'…초4 아들에 '저속노화' 식단 논란
# 뉴스 링크 = https://n.news.naver.com/mnews/article/031/0000859381
# ===============
# 뉴스 제목 = 8월 눈병·귓병 가장 많아…"물놀이 시 주의 필요"
# 뉴스 링크 = https://n.news.naver.com/mnews/article/584/0000028181
# ===============
# 뉴스 제목 = 이른 추석에, 호텔 셰프의 차례상차림 벌써 나왔다
# 뉴스 링크 = https://n.news.naver.com/mnews/article/016/0002345603
# ===============
# 뉴스 제목 = 소리 없이 찾아오는 ‘협심증’… 위험 알려주는 인공지능 개발돼
# 뉴스 링크 = https://n.news.naver.com/mnews/article/346/0000078428
# ===============
# 뉴스 제목 = [내일 날씨] "낮 최고 35도"… 전국 '폭염' 주의하세요
# 뉴스 링크 = https://n.news.naver.com/mnews/article/417/0001018906
# ===============
# 뉴스 제목 = 황보라, "얼굴에 뭘 붙인 거야?"...피부 진정된다지만 오래 놔뒀다간
# 뉴스 링크 = https://n.news.naver.com/mnews/article/296/0000080556
# ===============
# 뉴스 제목 = "30년 동안 잠을 안잤다고?"...밤낮 깨어있다는 40대女, 어떻게 가능?
# 뉴스 링크 = https://n.news.naver.com/mnews/article/296/0000080555
# ===============
# 뉴스 제목 = 아에로멕시코, '인천~멕시코시티' 직항 2년 만에 재개
# 뉴스 링크 = https://n.news.naver.com/mnews/article/421/0007710987
# ===============
# 뉴스 제목 = 7월 수입차 BMW 1위 탈환…벤츠·테슬라와 격차 벌려
# 뉴스 링크 = https://n.news.naver.com/mnews/article/092/0002340922
# ===============
# 뉴스 제목 = [르포]"쪄 죽겠다"…대청호 수해 쓰레기 수거 현장 더위와 전쟁
# 뉴스 링크 = https://n.news.naver.com/mnews/article/001/0014855300
# ===============
# 뉴스 제목 = 최소 열흘은 펄펄 끓을 한반도…역대 최고기온 '41도' 갈아 치울까
# 뉴스 링크 = https://n.news.naver.com/mnews/article/469/0000816123
# ===============
# 뉴스 제목 = [날씨] 이틀 연속 40℃ 육박 폭염...'한증막 더위' 10일 이상 더 간다
# 뉴스 링크 = https://n.news.naver.com/mnews/article/052/0002070328
# ===============
# 뉴스 제목 = [날씨] 한낮 체감온도 35도 안팎…내륙 중심 소나기
# 뉴스 링크 = https://n.news.naver.com/mnews/article/422/0000674747
# ===============
# 뉴스 제목 = [르포] "냉토시 안에도 땀이 줄줄"…부산 피서지도 '헉헉'
# 뉴스 링크 = https://n.news.naver.com/mnews/article/001/0014855252
# ===============
# 뉴스 제목 = "피 한 방울로 신장이식 환자 이식 거부 반응 확인 가능"
# 뉴스 링크 = https://n.news.naver.com/mnews/article/346/0000078424
# ===============
# 뉴스 제목 = 유전자 돌연변이 없는 난소암, 면역항암제 치료 가능성 제시
# 뉴스 링크 = https://n.news.naver.com/mnews/article/346/0000078422
# ===============
# 뉴스 제목 = 올해 열대야 12일 달해…'사상 최악 폭염' 2018년보다 많아
# 뉴스 링크 = https://n.news.naver.com/mnews/article/001/0014855230
# ===============
# 뉴스 제목 = 5초 만에 폐암 확인… ‘이 손가락 테스트’ 아시나요?
# 뉴스 링크 = https://n.news.naver.com/mnews/article/346/0000078419
# ===============
# 뉴스 제목 = [날씨] 서울 낮 체감 35℃...찜통 더위? 시원한 계곡은 달라요!
# 뉴스 링크 = https://n.news.naver.com/mnews/article/052/0002070314
# ===============
# 뉴스 제목 = "샤넬은 살 만큼 샀다"…요즘 잘나가는 '금수저룩' [안혜원의 명품의세계]
# 뉴스 링크 = https://n.news.naver.com/mnews/article/015/0005018165
# ===============
# 뉴스 제목 = 혈당 조절 위해 ‘이 식습관’ 바꿨더니... 체중에 큰 변화가?
# 뉴스 링크 = https://n.news.naver.com/mnews/article/296/0000080550
# ===============
# 뉴스 제목 = '이 암' 극복하고, 아버지와 1600km 자전거 완주 목표… 英 소년, 사연 봤더니?
# 뉴스 링크 = https://n.news.naver.com/mnews/article/346/0000078418
# ===============
# 뉴스 제목 = [날씨] 전국 대부분 지역 폭염경보…요란한 소나기 유의
# 뉴스 링크 = https://n.news.naver.com/mnews/article/422/0000674739
# ===============
# 뉴스 제목 = 찬 음식 먹었더니 설사 줄줄… ‘이때’ 먹으면 도움 되는 음식 3
# 뉴스 링크 = https://n.news.naver.com/mnews/article/346/0000078416
# ===============
# 뉴스 제목 = 태극기 휘날린 대한민국 양궁… 현대차그룹 첨단기술 ‘적중’
# 뉴스 링크 = https://n.news.naver.com/mnews/article/020/0003580327
# ===============
# 뉴스 제목 = [날씨] 이틀째 40℃ 육박 극한 폭염...도로 표면 온도는?
# 뉴스 링크 = https://n.news.naver.com/mnews/article/052/0002070300
# ===============
# 뉴스 제목 = 폭염에 지난주 평일 4백여명 응급실행…4명 사망
# 뉴스 링크 = https://n.news.naver.com/mnews/article/374/0000396098
# ===============
# 뉴스 제목 = “국내에서만 유행하는 일본뇌염바이러스(5형), 기존 바이러스보다 더 치명적”
# 뉴스 링크 = https://n.news.naver.com/mnews/article/022/0003957238
# ===============
# 뉴스 제목 = [날씨] 밤낮 가리지 않는 무더위…전국 폭염특보 발효 중
# 뉴스 링크 = https://n.news.naver.com/mnews/article/422/0000674731
# ===============
# 뉴스 제목 = "주말에만 5명 숨졌다"…'살인 폭염'에 올해 온열질환 사망자 13명
# 뉴스 링크 = https://n.news.naver.com/mnews/article/011/0004376111
# ===============
# 뉴스 제목 = 계곡에 사는 가재를 꼬시는 엉뚱한 노래
# 뉴스 링크 = https://n.news.naver.com/mnews/article/047/0002441996
# ===============
# 뉴스 제목 = 나이 들수록 男이 신경 써야 할 것들...컨디션 최상으로 유지하려면?
# 뉴스 링크 = https://n.news.naver.com/mnews/article/296/0000080548
# ===============
# 뉴스 제목 = 한국에만 있는 '5형 일본뇌염', 기존 백신으론 방어 못해
# 뉴스 링크 = https://n.news.naver.com/mnews/article/584/0000028176
# ===============
# 뉴스 제목 = 배우 황승언, 수영복 입고 ‘애플힙’ 뒤태 뽐내… 평소 먹는 식단 뭘까?
# 뉴스 링크 = https://n.news.naver.com/mnews/article/346/0000078414
# ===============
# 뉴스 제목 = ‘안정형 협심증’도 관상동맥질환 예측 성공
# 뉴스 링크 = https://n.news.naver.com/mnews/article/016/0002345496
# ===============

# %% [markdown]
# ### 2. Image 다운로드
# * referer 요청 헤더를 반드시 설정해야 한다.

# %%
import requests
import os

req_header = {
    # 캐슬2:만인지상 39화
    'referer':'https://comic.naver.com/webtoon/detail?titleId=807178&no=52&week=wed'
}
#jpg filename list
img_urls = [
    'https://image-comic.pstatic.net/webtoon/807178/52/20240514192317_36cba3602eb05145c7710b4f4a8354ec_IMAG01_6.jpg',
    'https://image-comic.pstatic.net/webtoon/807178/52/20240514192317_36cba3602eb05145c7710b4f4a8354ec_IMAG01_7.jpg',
    'https://image-comic.pstatic.net/webtoon/807178/52/20240514192317_36cba3602eb05145c7710b4f4a8354ec_IMAG01_8.jpg'
]
for img_url in img_urls:
    res = requests.get(img_url, headers=req_header)
    if res.ok:
        # binary 데이터 추출
        img_data = res.content
        # url에서 file name 가져오기
        file_name = os.path.basename(img_url)
        with open(file_name, 'wb') as file:
            print(f'writing to {file_name} ({len(img_data):,} bytes)')
            file.write(img_data)
    else:
        print(f'Error 발생 {res.status_code}')
# Out:
# writing to 20240514192317_36cba3602eb05145c7710b4f4a8354ec_IMAG01_6.jpg (240,671 bytes)
# writing to 20240514192317_36cba3602eb05145c7710b4f4a8354ec_IMAG01_7.jpg (324,850 bytes)
# writing to 20240514192317_36cba3602eb05145c7710b4f4a8354ec_IMAG01_8.jpg (243,951 bytes)

# %% [markdown]
# * 현재 요청된 페이지(특정 회차)의 image 모두 다운로드 해보기

# %%
import requests
import os

webtoon_url = 'https://comic.naver.com/webtoon/detail?titleId=807178&no=40&week=wed'
req_header = {
    'referer': webtoon_url
}
# jpg image file명을 먼저 알아내기
res = requests.get(webtoon_url)
if res.ok: #200
    # xxx.jpg 파일명 목록 가져오기
    soup = BeautifulSoup(res.text, 'html.parser')
    print(len(soup.select("img[src$='.jpg']")))
    print(len(soup.select("img[src*='IMAG01']")))
    img_tag_list = soup.select("img[src*='IMAG01']") 
    
    #image 파일명을 저장할 리스트 선언
    img_url_list = []
    for img_tag in img_tag_list:
        # print(img_tag['src'])
        # image 태그의 src 속성 값을 추출해서 list에 추가하기
        # ['http://x1.jpg', 'http://x2.jpg', ...]
        img_url_list.append(img_tag['src'])
    image_dir_name = 'img'
    # img 디렉토리가 없으면 img 디렉토리 생성하기
    if not os.path.isdir(image_dir_name):
        os.mkdir(image_dir_name)

    for idx, img_url in enumerate(img_url_list, 1):
        res = requests.get(img_url, headers=req_header)
        print(idx, res.status_code)
        if res.ok:
            # binary 데이터 추출
            img_data = res.content
            # url에서 file name 가져오기
            file_name = os.path.basename(img_url)
            #img/xxxx.jpg
            dir_name = os.path.join(image_dir_name, file_name)
            
            with open(dir_name, 'wb') as file:
                print(f'writing to {dir_name} ({len(img_data):,} bytes)')
                file.write(img_data)
        else:
            print(f'Error 발생 {res.status_code}')
else:
    print(res.status_code)
# Out:
# 160
# 101
# 1 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_1.jpg (209,668 bytes)
# 2 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_2.jpg (187,682 bytes)
# 3 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_3.jpg (209,589 bytes)
# 4 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_4.jpg (219,953 bytes)
# 5 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_5.jpg (209,406 bytes)
# 6 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_6.jpg (133,737 bytes)
# 7 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_7.jpg (135,037 bytes)
# 8 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_8.jpg (308,193 bytes)
# 9 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_9.jpg (117,276 bytes)
# 10 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_10.jpg (242,863 bytes)
# 11 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_11.jpg (201,699 bytes)
# 12 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_12.jpg (177,247 bytes)
# 13 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_13.jpg (251,995 bytes)
# 14 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_14.jpg (327,294 bytes)
# 15 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_15.jpg (158,818 bytes)
# 16 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_16.jpg (121,531 bytes)
# 17 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_17.jpg (121,100 bytes)
# 18 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_18.jpg (114,093 bytes)
# 19 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_19.jpg (151,669 bytes)
# 20 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_20.jpg (179,977 bytes)
# 21 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_21.jpg (161,598 bytes)
# 22 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_22.jpg (73,210 bytes)
# 23 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_23.jpg (241,961 bytes)
# 24 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_24.jpg (136,838 bytes)
# 25 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_25.jpg (306,213 bytes)
# 26 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_26.jpg (150,067 bytes)
# 27 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_27.jpg (124,275 bytes)
# 28 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_28.jpg (232,513 bytes)
# 29 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_29.jpg (274,076 bytes)
# 30 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_30.jpg (132,488 bytes)
# 31 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_31.jpg (177,905 bytes)
# 32 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_32.jpg (159,167 bytes)
# 33 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_33.jpg (225,533 bytes)
# 34 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_34.jpg (209,465 bytes)
# 35 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_35.jpg (260,002 bytes)
# 36 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_36.jpg (140,931 bytes)
# 37 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_37.jpg (82,286 bytes)
# 38 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_38.jpg (167,362 bytes)
# 39 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_39.jpg (216,183 bytes)
# 40 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_40.jpg (254,596 bytes)
# 41 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_41.jpg (125,887 bytes)
# 42 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_42.jpg (135,640 bytes)
# 43 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_43.jpg (125,718 bytes)
# 44 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_44.jpg (122,070 bytes)
# 45 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_45.jpg (92,418 bytes)
# 46 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_46.jpg (354,316 bytes)
# 47 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_47.jpg (45,728 bytes)
# 48 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_48.jpg (204,883 bytes)
# 49 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_49.jpg (199,496 bytes)
# 50 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_50.jpg (110,656 bytes)
# 51 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_51.jpg (129,218 bytes)
# 52 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_52.jpg (113,235 bytes)
# 53 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_53.jpg (133,318 bytes)
# 54 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_54.jpg (110,914 bytes)
# 55 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_55.jpg (129,913 bytes)
# 56 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_56.jpg (304,773 bytes)
# 57 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_57.jpg (239,546 bytes)
# 58 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_58.jpg (327,568 bytes)
# 59 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_59.jpg (207,873 bytes)
# 60 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_60.jpg (244,450 bytes)
# 61 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_61.jpg (194,645 bytes)
# 62 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_62.jpg (107,026 bytes)
# 63 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_63.jpg (131,202 bytes)
# 64 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_64.jpg (101,675 bytes)
# 65 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_65.jpg (211,601 bytes)
# 66 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_66.jpg (133,108 bytes)
# 67 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_67.jpg (119,104 bytes)
# 68 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_68.jpg (71,001 bytes)
# 69 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_69.jpg (290,474 bytes)
# 70 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_70.jpg (190,942 bytes)
# 71 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_71.jpg (152,723 bytes)
# 72 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_72.jpg (300,598 bytes)
# 73 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_73.jpg (125,988 bytes)
# 74 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_74.jpg (201,918 bytes)
# 75 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_75.jpg (344,279 bytes)
# 76 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_76.jpg (236,177 bytes)
# 77 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_77.jpg (247,506 bytes)
# 78 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_78.jpg (247,620 bytes)
# 79 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_79.jpg (188,616 bytes)
# 80 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_80.jpg (193,319 bytes)
# 81 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_81.jpg (132,065 bytes)
# 82 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_82.jpg (208,525 bytes)
# 83 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_83.jpg (172,382 bytes)
# 84 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_84.jpg (325,081 bytes)
# 85 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_85.jpg (196,553 bytes)
# 86 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_86.jpg (306,602 bytes)
# 87 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_87.jpg (152,415 bytes)
# 88 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_88.jpg (154,542 bytes)
# 89 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_89.jpg (105,130 bytes)
# 90 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_90.jpg (100,494 bytes)
# 91 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_91.jpg (191,680 bytes)
# 92 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_92.jpg (226,902 bytes)
# 93 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_93.jpg (262,122 bytes)
# 94 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_94.jpg (226,568 bytes)
# 95 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_95.jpg (155,763 bytes)
# 96 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_96.jpg (141,865 bytes)
# 97 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_97.jpg (119,342 bytes)
# 98 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_98.jpg (94,679 bytes)
# 99 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_99.jpg (229,880 bytes)
# 100 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_100.jpg (249,614 bytes)
# 101 200
# writing to img\20240321124034_753beee07ee054844e3f9ad73182bc6f_IMAG01_101.jpg (34,307 bytes)

# %% [markdown]
# ### 3. 파일 업로드 하기
# * http://httpbin.org/post 업로드 요청을 할 수 있는 url

# %%
import requests

upload_dict = {
    'img1': open('img/f1.jpg', 'rb'),
    'img2': open('img/f2.jpg', 'rb')
}
url = 'http://httpbin.org/post'
res = requests.post(url, files=upload_dict)
print(res.status_code)
#밑에 code 실행시 양이 너무 많아 일단 주석 처리
#print(res.json()['files']['img1'])
# Out:
# 200

# %% [markdown]
# ### 4. 단축 URL 생성하는 Open API 사용하기
# * urllib 사용

# %%
import os
import sys
import urllib.request

client_id = "SzpLoEexp7S0XeeJvwQC" # 개발자센터에서 발급받은 Client ID 값
client_secret = "SRqBx0JQBJ" # 개발자센터에서 발급받은 Client Secret 값
encText = urllib.parse.quote("https://drive.google.com/drive/folders/1NTJUrAWgazPEUP3ogrlucbn2slhby5M8")
data = "url=" + encText
url = "https://openapi.naver.com/v1/util/shorturl"

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)

response = urllib.request.urlopen(request, data=data.encode("utf-8"))
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {"result":{"url":"https://me2.do/FjbrKA2g","hash":"FjbrKA2g","orgUrl":"https://drive.google.com/drive/folders/1NTJUrAWgazPEUP3ogrlucbn2slhby5M8"},"message":"ok","code":"200"}

# %% [markdown]
# * requests를 사용하는 코드로 변경하기
# * [requests docs](https://requests.readthedocs.io/en/latest/user/quickstart/)

# %%
import requests

client_id = "SzpLoEexp7S0XeeJvwQC" # 개발자센터에서 발급받은 Client ID 값
client_secret = "SRqBx0JQBJ" # 개발자센터에서 발급받은 Client Secret 값

origin_url = "https://drive.google.com/drive/folders/1NTJUrAWgazPEUP3ogrlucbn2slhby5M8"

req_param = {
    'url': origin_url
}
req_header = {
    "X-Naver-Client-Id": client_id,
    "X-Naver-Client-Secret": client_secret
}

# %% [markdown]
# ### 5. 블로그 검색하기

# %%
import requests
import pprint

headers = {
    'X-Naver-Client-Id': 'V',
    'X-Naver-Client-Secret': 'y_',
}

payload = {
    'query': '파이썬',
    'display': 100,
    'sort': 'sim'
}

url = 'https://openapi.naver.com/v1/search/blog.json'

res = requests.get(url, params=payload, headers=headers)
items_data = res.json()['items']
#print(items_data)

items_list = list()
item_list = []
for item in items_data:
#     print(item)
    item_list.append(item['title'])
    item_list.append(item['bloggername'])
    item_list.append(item['description'])
    item_list.append(item['bloggerlink'])
    item_list.append(item['link'])

    items_list.append(item_list)
    item_list = []

print(items_list)

with open('data/nhnblog.txt','w',encoding="utf-8")as file:
    for items in items_list:
        for item in items:
            item = item + '\n'
            file.write(item)
        file.write('-'*150+'\n')
